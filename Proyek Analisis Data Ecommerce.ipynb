# %% [markdown]
# # Proyek Analisis Data: Data E-commerce
# - Nama: Yeni Rismawati
# - Email: yenirisma72@gmail.com
# - Id Dicoding: yeni_rismawati

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Produk apa yang paling banyak terjual?
# - Produk apa yang paling sedikit terjual?
# - Seberapa tinggi tingkat kepuasaan pelanggan?
# - Motedo payment apa yang paling sering digunakan?

# %% [markdown]
# ## Menyiapkan semua library yang dibuthkan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
customers_df = pd.read_csv("D:\\4 COURSE\\1 IDCAMP\\Data Science\\E-commerce-public-dataset\\E-Commerce Public Dataset\\customers_dataset.csv", delimiter=",")
customers_df
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %%
order_items_df = pd.read_csv("D:\\4 COURSE\\1 IDCAMP\\Data Science\\E-commerce-public-dataset\\E-Commerce Public Dataset\\order_items_dataset.csv", delimiter=",")
order_items_df
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
order_payment_df = pd.read_csv("D:\\4 COURSE\\1 IDCAMP\\Data Science\\E-commerce-public-dataset\\E-Commerce Public Dataset\\order_payments_dataset.csv", delimiter=",")
order_payment_df
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value
# ...

# %%
order_reviews_df = pd.read_csv("D:\\4 COURSE\\1 IDCAMP\\Data Science\\E-commerce-public-dataset\\E-Commerce Public Dataset\\order_reviews_dataset.csv", delimiter=",")
order_reviews_df
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# ...

# %%
product_df = pd.read_csv("D:\\4 COURSE\\1 IDCAMP\\Data Science\\E-commerce-public-dataset\\E-Commerce Public Dataset\\products_dataset.csv", delimiter=",")
product_df
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...

# %%
sellers_df = pd.read_csv("D:\\4 COURSE\\1 IDCAMP\\Data Science\\E-commerce-public-dataset\\E-Commerce Public Dataset\\sellers_dataset.csv", delimiter=",")
sellers_df
# Out:
#                              seller_id  seller_zip_code_prefix  \
# 0     3442f8959a84dea7ee197c632cb2df15                   13023
# 1     d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2     ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3     c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4     51a04a8a6bdcb23deccc82b0b80742cf                   12914
# ...                                ...                     ...
# 3090  98dddbc4601dd4443ca174359b237166                   87111
# 3091  f8201cab383e484733266d1906e2fdfa                   88137
# 3092  74871d19219c7d518d0090283e03c137                    4650
# 3093  e603cf3fec55f8697c9059638d6c8eb5                   96080
# 3094  9e25199f6ef7e7c347120ff175652c3b                   12051
#
#             seller_city seller_state
# 0              campinas           SP
# 1            mogi guacu           SP
# 2        rio de janeiro           RJ
# 3             sao paulo           SP
# ...

# %%
geolocation_df = pd.read_csv("D:\\4 COURSE\\1 IDCAMP\\Data Science\\E-commerce-public-dataset\\E-Commerce Public Dataset\\geolocation_dataset.csv", delimiter=",")
geolocation_df
# Out:
#          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                               1037       -23.545621       -46.639292
# 1                               1046       -23.546081       -46.644820
# 2                               1046       -23.546129       -46.642951
# 3                               1041       -23.544392       -46.639499
# 4                               1035       -23.541578       -46.641607
# ...                              ...              ...              ...
# 1000158                        99950       -28.068639       -52.010705
# 1000159                        99900       -27.877125       -52.224882
# 1000160                        99950       -28.071855       -52.014716
# 1000161                        99980       -28.388932       -51.846871
# 1000162                        99950       -28.070104       -52.018658
#
#         geolocation_city geolocation_state
# 0              sao paulo                SP
# ...

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# **1. Assesing customer_df**

# %%
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
customers_df.isna().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
customers_df.duplicated().sum()
# Out:
# 0

# %%
customers_df.describe()
# Out:
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000

# %% [markdown]
# **2. Assesing orders_item_df**

# %%
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %% [markdown]
# variabel **shipping_limit_date** harusnya bertipe datetime

# %%
order_items_df.isna().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
order_items_df.duplicated().sum()
# Out:
# 0

# %%
order_items_df.describe()
# Out:
#        order_item_id          price  freight_value
# count  112650.000000  112650.000000  112650.000000
# mean        1.197834     120.653739      19.990320
# std         0.705124     183.633928      15.806405
# min         1.000000       0.850000       0.000000
# 25%         1.000000      39.900000      13.080000
# 50%         1.000000      74.990000      16.260000
# 75%         1.000000     134.900000      21.150000
# max        21.000000    6735.000000     409.680000

# %% [markdown]
# **3. Assesing order_payment_df**

# %%
order_payment_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
order_payment_df.duplicated().sum()
# Out:
# 0

# %%
order_payment_df.describe()
# Out:
#        payment_sequential  payment_installments  payment_value
# count       103886.000000         103886.000000  103886.000000
# mean             1.092679              2.853349     154.100380
# std              0.706584              2.687051     217.494064
# min              1.000000              0.000000       0.000000
# 25%              1.000000              1.000000      56.790000
# 50%              1.000000              1.000000     100.000000
# 75%              1.000000              4.000000     171.837500
# max             29.000000             24.000000   13664.080000

# %% [markdown]
# **3. Assesing order_payment_df**

# %%
order_payment_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
order_payment_df.isna().sum()
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %%
order_payment_df.duplicated().sum()
# Out:
# 0

# %%
order_payment_df.describe()
# Out:
#        payment_sequential  payment_installments  payment_value
# count       103886.000000         103886.000000  103886.000000
# mean             1.092679              2.853349     154.100380
# std              0.706584              2.687051     217.494064
# min              1.000000              0.000000       0.000000
# 25%              1.000000              1.000000      56.790000
# 50%              1.000000              1.000000     100.000000
# 75%              1.000000              4.000000     171.837500
# max             29.000000             24.000000   13664.080000

# %% [markdown]
# **4. Assessing order_review_df**

# %%
order_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %% [markdown]
# Terdapat keanehan di **review_comment_title dan review_comment_message** dimana nilainya tidak sama dengan yang lain

# %%
order_reviews_df.isna().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
order_reviews_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **5. Assessing product_df**

# %%
product_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %% [markdown]
# pada **product_category_name** nantinya akan dirubah menggunakan bahasa inggris agar lebih mudah dipahami

# %%
product_df.duplicated().sum()
# Out:
# 0

# %%
product_df.describe()
# Out:
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count         32341.000000                32341.000000        32341.000000
# mean             48.476949                  771.495285            2.188986
# std              10.245741                  635.115225            1.736766
# min               5.000000                    4.000000            1.000000
# 25%              42.000000                  339.000000            1.000000
# 50%              51.000000                  595.000000            1.000000
# 75%              57.000000                  972.000000            3.000000
# max              76.000000                 3992.000000           20.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32949.000000       32949.000000       32949.000000
# mean        2276.472488          30.815078          16.937661
# std         4282.038731          16.914458          13.637554
# ...

# %% [markdown]
# **6. Assessing seller_df**

# %%
sellers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %%
sellers_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **7. Assessing Geolocation_df**

# %%
geolocation_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  object
#  4   geolocation_state            1000163 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 38.2+ MB

# %%
geolocation_df.duplicated().sum()
# Out:
# 261831

# %% [markdown]
# ada banyak data yang duplicated

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# merubah variabel **shipping_limit_date** dari tabel **orders_item_df** menjadi bertipe datetime

# %%
order_items_df['shipping_limit_date'] = pd.to_datetime(order_items_df['shipping_limit_date'])

# %%
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  datetime64[ns]
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 6.0+ MB

# %% [markdown]
# karena kolom **review_comment_title** dan **review_comment_message** banyak yang missing, dan isi dari kedua kolom tersebut berupa review, dimana hal tersebut dapat terwakilkan dari kolom **review_score**, maka kita drop kedua kolom tersebut

# %%
order_reviews_df= order_reviews_df.drop(['review_comment_title', 'review_comment_message'], axis=1)

# %%
order_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_creation_date     99224 non-null  object
#  4   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
product_df
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...

# %%
#merubah dalam bahasa inggris agar lebih mudah dipahami

product_df.replace({"beleza_saude":"health_beauty",
                    "informatica_acessorios":"computers_accessories",
                    "automotivo":"auto",
                    "cama_mesa_banho":"bed_bath_table",
                    "moveis_decoracao":"furniture_decor",
                    "esporte_lazer":"sports_leisure",
                    "perfumaria":"perfumery",
                    "utilidades_domesticas":"housewares",
                    "telefonia":"telephony",
                    "relogios_presentes":"watches_gifts",
                    "alimentos_bebidas":"food_drink",
                    "bebes":"baby",
                    "papelaria":"stationery",
                    "tablets_impressao_imagem":"tablets_printing_image",
                    "brinquedos":"toys",
                    "telefonia_fixa":"fixed_telephony",
                    "ferramentas_jardim":"garden_tools",
                    "fashion_bolsas_e_acessorios":"fashion_bags_accessories",
                    "eletroportateis":"small_appliances",
                    "consoles_games":"consoles_games",
                    "audio":"audio",
                    "fashion_calcados":"fashion_shoes",
                    "cool_stuff":"cool_stuff",
                    "malas_acessorios":"luggage_accessories",
                    "climatizacao":"air_conditioning",
                    "construcao_ferramentas_construcao":"construction_tools_construction",
                    "moveis_cozinha_area_de_servico_jantar_e_jardim":"kitchen_dining_laundry_garden_furniture",
                    "construcao_ferramentas_jardim":"costruction_tools_garden",
                    "fashion_roupa_masculina":"fashion_male_clothing",
                    "pet_shop":"pet_shop",
                    "moveis_escritorio":"office_furniture",
                    "market_place":"market_place",
                    "eletronicos":"electronics",
                    "eletrodomesticos":"home_appliances",
                    "artigos_de_festas":"party_supplies",
                    "casa_conforto":"home_confort",
                    "construcao_ferramentas_ferramentas":"costruction_tools_tools",
                    "agro_industria_e_comercio":"agro_industry_and_commerce",
                    "moveis_colchao_e_estofado":"furniture_mattress_and_upholstery",
                    "livros_tecnicos":"books_technical",
                    "casa_construcao":"home_construction",
                    "instrumentos_musicais":"musical_instruments",
                    "moveis_sala":"furniture_living_room",
                    "construcao_ferramentas_iluminacao":"construction_tools_lights",
                    "industria_comercio_e_negocios":"industry_commerce_and_business",
                    "alimentos":"food",
                    "artes":"art",
                    "moveis_quarto":"furniture_bedroom",
                    "livros_interesse_geral":"books_general_interest",
                    "construcao_ferramentas_seguranca":"construction_tools_safety",
                    "fashion_underwear_e_moda_praia":"fashion_underwear_beach",
                    "fashion_esporte":"fashion_sport",
                    "sinalizacao_e_seguranca":"signaling_and_security",
                    "pcs":"computers",
                    "artigos_de_natal":"christmas_supplies",
                    "fashion_roupa_feminina":"fashio_female_clothing",
                    "eletrodomesticos_2":"home_appliances_2",
                    "livros_importados":"books_imported",
                    "bebidas":"drinks",
                    "cine_foto":"cine_photo",
                    "la_cuisine":"la_cuisine",
                    "musica":"music",
                    "casa_conforto_2":"home_comfort_2",
                    "portateis_casa_forno_e_cafe":"small_appliances_home_oven_and_coffee",
                    "cds_dvds_musicais":"cds_dvds_musicals",
                    "dvds_blu_ray":"dvds_blu_ray",
                    "flores":"flowers",
                    "artes_e_artesanato":"arts_and_craftmanship",
                    "fraldas_higiene":"diapers_and_hygiene",
                    "fashion_roupa_infanto_juvenil":"fashion_childrens_clothes",
                    "seguros_e_servicos":"security_and_services"}, inplace = True)

# %%
product_df
# Out:
#                              product_id      product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                  perfumery
# 1      3aa071139cb16b67ca9e5dea641aaa2f                        art
# 2      96bd76ec8810374ed1b65e291975717f             sports_leisure
# 3      cef67bcfe19066a932b7673e239eb23d                       baby
# 4      9dc1a7de274444849c219cff195d0b71                 housewares
# ...                                 ...                        ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0            furniture_decor
# 32947  bf4538d88321d0fd4412a93c974510e6  construction_tools_lights
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c             bed_bath_table
# 32949  83808703fc0706a22e264b9d75f04a2e      computers_accessories
# 32950  106392145fca363410d287a815be6de4             bed_bath_table
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                     40.0                       287.0                 1.0
# ...

# %%
#mengatasi duplicated data

geolocation_df.drop_duplicates(inplace = True)

# %%
geolocation_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### customer_df

# %%
customers_df.describe(include="all")
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     06b8999e2fba1a1fbc88172c00ba8bc7  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# ...

# %%
customers_df
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %%
group_customer_city = customers_df['customer_city'].value_counts()
print(group_customer_city)
# Out:
# sao paulo            15540
# rio de janeiro        6882
# belo horizonte        2773
# brasilia              2131
# curitiba              1521
#                      ...
# bequimao                 1
# andarai                  1
# vargem grande            1
# curvelandia              1
# eugenio de castro        1
# Name: customer_city, Length: 4119, dtype: int64

# %%
customers_df.groupby(by="customer_city").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_city
# sao paulo         15540
# rio de janeiro     6882
# belo horizonte     2773
# brasilia           2131
# curitiba           1521
#                   ...
# ibiara                1
# rio espera            1
# rio dos indios        1
# rio dos cedros        1
# lagoao                1
# Name: customer_id, Length: 4119, dtype: int64

# %%
customers_df.groupby(by="customer_state").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# PE     1652
# CE     1336
# PA      975
# MT      907
# MA      747
# MS      715
# PB      536
# PI      495
# RN      485
# AL      413
# SE      350
# TO      280
# RO      253
# AM      148
# AC       81
# AP       68
# RR       46
# Name: customer_id, dtype: int64

# %% [markdown]
# ### order_items

# %%
order_items_df.describe(include="all")
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   """Entry point for launching an IPython kernel.
#                                 order_id  order_item_id  \
# count                             112650  112650.000000
# unique                             98666            NaN
# top     8272b63d03f5f79c56e9e4120aec44ef            NaN
# freq                                  21            NaN
# first                                NaN            NaN
# last                                 NaN            NaN
# mean                                 NaN       1.197834
# std                                  NaN       0.705124
# min                                  NaN       1.000000
# 25%                                  NaN       1.000000
# ...

# %% [markdown]
# dapat kita ketahui produk dan seller yang tertinggi

# %% [markdown]
# ### order_payment_df

# %%
order_payment_df.describe(include="all")
# Out:
#                                 order_id  payment_sequential payment_type  \
# count                             103886       103886.000000       103886
# unique                             99440                 NaN            5
# top     fa65dad1b0e818e3ccc5cb0e39231352                 NaN  credit_card
# freq                                  29                 NaN        76795
# mean                                 NaN            1.092679          NaN
# std                                  NaN            0.706584          NaN
# min                                  NaN            1.000000          NaN
# 25%                                  NaN            1.000000          NaN
# 50%                                  NaN            1.000000          NaN
# 75%                                  NaN            1.000000          NaN
# max                                  NaN           29.000000          NaN
#
#         payment_installments  payment_value
# ...

# %% [markdown]
# dapat dilihat bahwa payment type yang paling banyak digunakan adalah menggunakan credit card

# %%
order_payment_df.groupby(by="payment_type").order_id.nunique().sort_values(ascending=False)
# Out:
# payment_type
# credit_card    76505
# boleto         19784
# voucher         3866
# debit_card      1528
# not_defined        3
# Name: order_id, dtype: int64

# %% [markdown]
# ### order_review_df

# %%
order_reviews_df.describe(include="all")
# Out:
#                                review_id                          order_id  \
# count                              99224                             99224
# unique                             98410                             98673
# top     7b606b0d57b078384f0b58eac1d41d78  c88b1d1b157a9999ce368f218a407141
# freq                                   3                                 3
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         review_score review_creation_date review_answer_timestamp
# ...

# %% [markdown]
# review score terdiri dari 1-5, dan jika dilihat mean atau
# rata-rata score adalah 4, maka dapat dikatakan bahwa product mendapat feedback yang baik

# %% [markdown]
# kita akan membagi menjadi 2 kelas, dimana review dengan skor 1-2 (bad) dan skor 3-5 (good)

# %%
order_reviews_df["review_score_group"] = order_reviews_df.review_score.apply(lambda x: "Bad" if x <= 2 else("Good"))
order_reviews_df.groupby(by="review_score_group").order_id.nunique().sort_values(ascending=False)
# Out:
# review_score_group
# Good    84236
# Bad     14533
# Name: order_id, dtype: int64

# %% [markdown]
# ### product_df

# %%
product_df.describe(include="all")
# Out:
#                               product_id product_category_name  \
# count                              32951                 32341
# unique                             32951                    73
# top     1e9e8ef04dbcff4541ed26657ea517e5        bed_bath_table
# freq                                   1                  3029
# mean                                 NaN                   NaN
# std                                  NaN                   NaN
# min                                  NaN                   NaN
# 25%                                  NaN                   NaN
# 50%                                  NaN                   NaN
# 75%                                  NaN                   NaN
# max                                  NaN                   NaN
#
#         product_name_lenght  product_description_lenght  product_photos_qty  \
# count          32341.000000                32341.000000        32341.000000
# ...

# %% [markdown]
# dapat kita ketahui produk yang paling banyak adalah bed_bath_table

# %%
product_df.groupby(by="product_category_name").product_id.nunique().sort_values(ascending=False)
# Out:
# product_category_name
# bed_bath_table               3029
# sports_leisure               2867
# furniture_decor              2657
# health_beauty                2444
# housewares                   2335
#                              ...
# home_comfort_2                  5
# fashion_childrens_clothes       5
# pc_gamer                        3
# security_and_services           2
# cds_dvds_musicals               1
# Name: product_id, Length: 73, dtype: int64

# %% [markdown]
# ### seller_df

# %%
sellers_df.describe(include="all")
# Out:
#                                seller_id  seller_zip_code_prefix seller_city  \
# count                               3095             3095.000000        3095
# unique                              3095                     NaN         611
# top     3442f8959a84dea7ee197c632cb2df15                     NaN   sao paulo
# freq                                   1                     NaN         694
# mean                                 NaN            32291.059451         NaN
# std                                  NaN            32713.453830         NaN
# min                                  NaN             1001.000000         NaN
# 25%                                  NaN             7093.500000         NaN
# 50%                                  NaN            14940.000000         NaN
# 75%                                  NaN            64552.500000         NaN
# max                                  NaN            99730.000000         NaN
#
#        seller_state
# count          3095
# ...

# %%
sellers_df.groupby(by="seller_city").seller_id.nunique().sort_values(ascending=False).reset_index().head(10)
# Out:
#       seller_city  seller_id
# 0       sao paulo        694
# 1        curitiba        127
# 2  rio de janeiro         96
# 3  belo horizonte         68
# 4  ribeirao preto         52
# 5       guarulhos         50
# 6        ibitinga         49
# 7     santo andre         45
# 8        campinas         41
# 9         maringa         40

# %% [markdown]
# ### Explore ...

# %% [markdown]
# **Tabel order_item dengan tabel product**

# %%
merge_product_df = pd.merge(
        left = order_items_df,
        right = product_df,
        how = "left",
        left_on = "product_id",
        right_on = "product_id")

merge_product_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value product_category_name  \
# 0 2017-09-19 09:45:35   58.90          13.29            cool_stuff
# 1 2017-05-03 11:05:13  239.90          19.93              pet_shop
# ...

# %%
most_sold_product = merge_product_df.groupby(by="product_category_name").order_id.nunique().sort_values(ascending=False).reset_index().head(10)
most_sold_product = most_sold_product.rename(columns={"order_id": "order"})
most_sold_product
# Out:
#    product_category_name  order
# 0         bed_bath_table   9417
# 1          health_beauty   8836
# 2         sports_leisure   7720
# 3  computers_accessories   6689
# 4        furniture_decor   6449
# 5             housewares   5884
# 6          watches_gifts   5624
# 7              telephony   4199
# 8                   auto   3897
# 9                   toys   3886

# %%
least_sold_product = merge_product_df.groupby(by="product_category_name").order_id.nunique().sort_values(ascending=True).reset_index().head(10)
least_sold_product = least_sold_product.rename(columns={"order_id": "order"})
least_sold_product
# Out:
#                            product_category_name  order
# 0                          security_and_services      2
# 1                      fashion_childrens_clothes      8
# 2                                       pc_gamer      8
# 3                              cds_dvds_musicals     12
# 4                                     la_cuisine     13
# 5  portateis_cozinha_e_preparadores_de_alimentos     14
# 6                          arts_and_craftmanship     23
# 7                                 home_comfort_2     24
# 8                            diapers_and_hygiene     27
# 9                                  fashion_sport     27

# %% [markdown]
# **Tabel sebelumnya dengan order review**

# %%
merge_order_review_df = pd.merge(
        left = merge_product_df,
        right = order_reviews_df,
        how = "left",
        left_on = "order_id",
        right_on = "order_id")

merge_order_review_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value product_category_name  \
# 0 2017-09-19 09:45:35   58.90          13.29            cool_stuff
# 1 2017-05-03 11:05:13  239.90          19.93              pet_shop
# ...

# %%
product_satisfaction = merge_order_review_df.groupby('product_category_name')['review_score'].mean().sort_values(ascending=False).reset_index().head(10)
product_satisfaction
# Out:
#                    product_category_name  review_score
# 0                      cds_dvds_musicals      4.642857
# 1              fashion_childrens_clothes      4.500000
# 2                 books_general_interest      4.446266
# 3                costruction_tools_tools      4.444444
# 4                                flowers      4.419355
# 5                         books_imported      4.400000
# 6                        books_technical      4.368421
# 7                             food_drink      4.315412
# 8                    luggage_accessories      4.315257
# 9  small_appliances_home_oven_and_coffee      4.302632

# %%
satisfied_customers = merge_order_review_df[merge_order_review_df['review_score'] >= 2]['order_id'].nunique()
total_customers = merge_order_review_df['order_id'].nunique()
satisfied_percentage = (satisfied_customers / total_customers) * 100
unsatisfied_customers = total_customers - satisfied_customers

satisfaction_tabel = pd.DataFrame({'Review':['Puas','Tidak Puas'],
                                   'Number Customer' : [satisfied_customers, unsatisfied_customers]})
print(satisfaction_tabel)
# Out:
#        Review  Number Customer
# 0        Puas            87139
# 1  Tidak Puas            11527

# %% [markdown]
# **Tabel merge sebelumnya dengan seller_df**

# %%
merge_seller_df = pd.merge(
        left = merge_order_review_df,
        right = sellers_df,
        how = "left",
        left_on = "seller_id",
        right_on = "seller_id")

merge_seller_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value product_category_name  \
# 0 2017-09-19 09:45:35   58.90          13.29            cool_stuff
# 1 2017-05-03 11:05:13  239.90          19.93              pet_shop
# ...

# %%
products_sold = merge_seller_df.groupby('seller_id')['product_id'].count().reset_index()
products_sold
# Out:
#                              seller_id  product_id
# 0     0015a82c2db000af6aaaf3ae2ecb0532           3
# 1     001cca7ae9ae17fb1caed9dfb1094831         239
# 2     001e6ad469a905060d959994f1b41e4f           1
# 3     002100f778ceb8431b7a1020ff7ab48f          56
# 4     003554e2dce176b5555353e4f3555ac8           1
# ...                                ...         ...
# 3090  ffcfefa19b08742c5d315f2791395ee5           1
# 3091  ffdd9f82b9a447f6f8d4b91554cc7dd3          20
# 3092  ffeee66ac5d5a62fe688b9d26f83f534          14
# 3093  fffd5413c0700ac820c7069d66d98c89          61
# 3094  ffff564a4f9085cd26170f4732393726          20
#
# [3095 rows x 2 columns]

# %%
top_sellers = products_sold.sort_values('product_id', ascending=False).head(10)
top_sellers
# Out:
#                              seller_id  product_id
# 1235  6560211a19b47992c3666cc44a7e94c0        2039
# 881   4a3ca9315b744ce9f8e9374361493884        2009
# 368   1f50f920176fa81dab994f9023523100        1940
# 2481  cc419e0650a3c5ba77189a1882b7556a        1819
# 2643  da8622b14eb17ae2831f4ac5b9dab84a        1574
# 1824  955fee9216a65b617aa5c0531780ce60        1501
# 192   1025f0e2d44d7041d6cf58b6550e0bfa        1443
# 1535  7c67e1448b00f6e969d365cea6b010ab        1375
# 2836  ea8482cd71df3c1969d7b9473ff13abc        1204
# 1505  7a67c85e85bb2ce8582c35f2203ad736        1175

# %%
top_sellers_with_city = top_sellers.merge(merge_seller_df[['seller_id', 'seller_city']], on='seller_id', how='left')
top_sellers_with_city
# Out:
#                               seller_id  product_id seller_city
# 0      6560211a19b47992c3666cc44a7e94c0        2039   sao paulo
# 1      6560211a19b47992c3666cc44a7e94c0        2039   sao paulo
# 2      6560211a19b47992c3666cc44a7e94c0        2039   sao paulo
# 3      6560211a19b47992c3666cc44a7e94c0        2039   sao paulo
# 4      6560211a19b47992c3666cc44a7e94c0        2039   sao paulo
# ...                                 ...         ...         ...
# 16074  7a67c85e85bb2ce8582c35f2203ad736        1175   sao paulo
# 16075  7a67c85e85bb2ce8582c35f2203ad736        1175   sao paulo
# 16076  7a67c85e85bb2ce8582c35f2203ad736        1175   sao paulo
# 16077  7a67c85e85bb2ce8582c35f2203ad736        1175   sao paulo
# 16078  7a67c85e85bb2ce8582c35f2203ad736        1175   sao paulo
#
# [16079 rows x 3 columns]

# %%
top_sellers_with_city.duplicated().sum()
# Out:
# 16069

# %%
top_sellers_with_city = top_sellers_with_city.drop_duplicates()
top_sellers_with_city = top_sellers_with_city.rename(columns={"product_id": "product terjual"})
top_sellers_with_city
# Out:
#                               seller_id  product terjual  \
# 0      6560211a19b47992c3666cc44a7e94c0             2039
# 2039   4a3ca9315b744ce9f8e9374361493884             2009
# 4048   1f50f920176fa81dab994f9023523100             1940
# 5988   cc419e0650a3c5ba77189a1882b7556a             1819
# 7807   da8622b14eb17ae2831f4ac5b9dab84a             1574
# 9381   955fee9216a65b617aa5c0531780ce60             1501
# 10882  1025f0e2d44d7041d6cf58b6550e0bfa             1443
# 12325  7c67e1448b00f6e969d365cea6b010ab             1375
# 13700  ea8482cd71df3c1969d7b9473ff13abc             1204
# 14904  7a67c85e85bb2ce8582c35f2203ad736             1175
#
#                  seller_city
# 0                  sao paulo
# 2039                ibitinga
# 4048   sao jose do rio preto
# 5988             santo andre
# 7807              piracicaba
# 9381               sao paulo
# 10882              sao paulo
# 12325        itaquaquecetuba
# 13700              sao paulo
# 14904              sao paulo

# %%
seller_location = merge_seller_df.groupby(['seller_city', 'seller_state'])['product_id'].count().reset_index()
seller_location
# Out:
#          seller_city seller_state  product_id
# 0           04482255           RJ           1
# 1    abadia de goias           GO           1
# 2     afonso claudio           ES           6
# 3    aguas claras df           SP           1
# 4           alambari           SP           5
# ..               ...          ...         ...
# 631    volta redonda           SP         151
# 632       votorantim           SP         267
# 633      votuporanga           SP         138
# 634          xanxere           SC           8
# 635            xaxim           SC           2
#
# [636 rows x 3 columns]

# %%
merge_payment_df = pd.merge(
        left = order_items_df,
        right = order_payment_df,
        how = "left",
        left_on = "order_id",
        right_on = "order_id")

merge_payment_df
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 117599  fffc94f6ce00a00581880bf54a75a037              1
# 117600  fffcd46ef2263f404302a634eb57f7eb              1
# 117601  fffce4705a9662cd70adb13d4a31832d              1
# 117602  fffe18544ffabc95dfada21779c9644f              1
# 117603  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
# Menghitung jumlah penggunaan setiap metode pembayaran
payment_counts = merge_payment_df['payment_type'].value_counts()
payment_counts
# Out:
# credit_card    86769
# boleto         22867
# voucher         6274
# debit_card      1691
# Name: payment_type, dtype: int64

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:  kategori produk apa saja yang paling banyak diminati

# %%
most_sold_product
# Out:
#    product_category_name  order
# 0         bed_bath_table   9417
# 1          health_beauty   8836
# 2         sports_leisure   7720
# 3  computers_accessories   6689
# 4        furniture_decor   6449
# 5             housewares   5884
# 6          watches_gifts   5624
# 7              telephony   4199
# 8                   auto   3897
# 9                   toys   3886

# %% [markdown]
# ### Pertanyaan 2: kategori produk apa saja yang paling banyak sedikit terjual

# %%
least_sold_product
# Out:
#                            product_category_name  order
# 0                          security_and_services      2
# 1                      fashion_childrens_clothes      8
# 2                                       pc_gamer      8
# 3                              cds_dvds_musicals     12
# 4                                     la_cuisine     13
# 5  portateis_cozinha_e_preparadores_de_alimentos     14
# 6                          arts_and_craftmanship     23
# 7                                 home_comfort_2     24
# 8                            diapers_and_hygiene     27
# 9                                  fashion_sport     27

# %% [markdown]
# ### Pertanyaan 3: metode pembayaran apa saja yang paling banyak digunakan oleh pelanggan

# %%
payment_count_df = pd.DataFrame({
    'payment_type': payment_counts.index,
    'count': payment_counts.values})

plt.bar(payment_count_df['payment_type'], payment_count_df['count'])
plt.xlabel('Payment Type', fontsize = 12)
plt.ylabel('Count', fontsize = 12)
plt.title('Most Common Payment')
plt.show()

# %% [markdown]
# ### Pertanyaan 4: seberapa puas pelanggan terhadap produk yang dibeli

# %%
satisfied_percentage = round((satisfied_customers / total_customers) * 100, 2)
satisfied_percentage ="Persentase kepuasaan pelanggan : " + str(satisfied_percentage) + '%'
satisfied_percentage
# Out:
# 'Persentase kepuasaan pelanggan : 88.32%'

# %%
satisfaction_tabel
# Out:
#        Review  Number Customer
# 0        Puas            87139
# 1  Tidak Puas            11527

# %%
# Prepare the data for the pie chart
data = satisfaction_tabel['Number Customer'].tolist()
labels = satisfaction_tabel['Review'].tolist()

# Create the pie chart
plt.pie(data, labels=labels, colors = ['blue', 'yellow'])
plt.title('Customer Review')
plt.axis('equal')
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# 1.  Produk apa yang paling banyak terjual? Produk yang paling diminati pembeli adalah produk dengan kategori **bed_bath_table** sejumlah **9417** terjual
# 2.  Produk apa yang paling sedikit terjual?Produk yang paling sedikit terjual adalah produk dengan kategori **security_and_services**, yang hanya terjual **2**
# 3. Motedo payment apa yang paling sering digunakan?Metode pembayaran yang paling sering digunakan pelanggan adalah dengan **credit card** yaitu sebanyak **86769 transaksi**
# 4. Seberapa tinggi tingkat kepuasaan pelanggan?Persentase kepuasan pelanggan terhadap produk lebih banyak yaitu mencapai **88%**

# %%
import pkg_resources
installed_packages = pkg_resources.working_set
installed_packages_list = sorted(["%s==%s" % (i.key, i.version) for i in installed_packages])
print(installed_packages_list)
# Out:
# ['absl-py==0.15.0', 'aiohttp==3.8.6', 'aiosignal==1.3.1', 'alabaster==0.7.12', 'altair==5.0.1', 'anaconda-client==1.7.2', 'anaconda-navigator==1.9.12', 'anaconda-project==0.8.3', 'anyio==3.7.1', 'argh==0.26.2', 'argon2-cffi-bindings==21.2.0', 'argon2-cffi==23.1.0', 'asn1crypto==1.3.0', 'astor==0.8.1', 'astroid==2.3.3', 'astropy==4.0', 'asttokens==2.4.0', 'async-timeout==4.0.3', 'asynctest==0.13.0', 'atomicwrites==1.3.0', 'attrs==19.3.0', 'autopep8==1.4.4', 'babel==2.8.0', 'backcall==0.1.0', 'backports.functools-lru-cache==1.6.4', 'backports.shutil-get-terminal-size==1.0.0', 'backports.tempfile==1.0', 'backports.weakref==1.0.post1', 'backports.zoneinfo==0.2.1', 'bcrypt==3.1.7', 'beautifulsoup4==4.8.2', 'bitarray==1.2.1', 'bkcharts==0.2', 'bleach==3.1.0', 'blinker==1.6.3', 'bokeh==2.4.3', 'boto==2.49.0', 'bottleneck==1.3.2', 'cachetools==5.3.1', 'certifi==2019.11.28', 'cffi==1.14.0', 'chardet==3.0.4', 'charset-normalizer==3.3.0', 'click==7.0', 'cloudpickle==1.3.0', 'clyent==1.2.2', 'co
# ...

# %%
merge_product_df.to_csv('merge_product_df.csv', index= False)

# %%
merge_order_review_df.to_csv('merge_order_review_df.csv', index = False)

# %%
merge_seller_df.to_csv('merge_seller_df.csv', index = False)

# %%
merge_payment_df.to_csv('merge_payment_df.csv', index = False)
